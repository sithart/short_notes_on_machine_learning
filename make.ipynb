# %% [markdown]
# # Script To Make Site
#
# This script converts all jupyter notebooks into markdown files, then converts all markdown files (jupyter and note) into a website ready to push to github.

# %% [markdown]
# ## Preliminaries

# %%
# Load libraries
import os
import re
import fileinput
import sys
from glob import glob
import shutil


# Create path to content
path = 'content/'

# %% [markdown]
# ## Find All Jupyter Notebooks

# %%
# Find all jupyter notebooks in all content folders
all_ipynb_files = [os.path.join(root, name)
                   for root, dirs, files in os.walk(path)
                       for name in files
                           if name.endswith((".ipynb"))]

# Remove all notebooks from checkpoint folders
ipynb_files = [ x for x in all_ipynb_files if ".ipynb_checkpoints" not in x ]

# %% [markdown]
# ## Convert All Jupyter Notebooks To Markdown

# %%
# For each file
for file in ipynb_files:
    # Convert into markdown
    os.system('jupyter nbconvert --to markdown {file}'.format(file=file))

# %% [markdown]
# ## Handle The Folders
#
# This really nasty code finds all the folders generated by the Juypter conversion (they end in `_files`) and then tries to rename them to remove the `_files` part (doing so is required by Hugo so the images can be seen). If an existing folder (without the `_files` part) exists, it moves all the files from the newly generated `_files` into the existing folder (so we retain any manual images like flashcard images in that existing folder) and then deletes the `_files` folder.

# %%
# Get all folders in directory
folders = [x[0] for x in os.walk(path)]

# Delete .ipynb checkpoint folders
folders = [ x for x in folders if ".ipynb_checkpoints" not in x ]

# For each folder
for folder_name in folders:
    # if _files in folder name
    if '_files' in folder_name:
        
        # Create a new folder name
        def rchop(thestring, ending):
            if thestring.endswith(ending):
                return thestring[:-len(ending)]
            return thestring

        new_folder_name = rchop(folder_name, '_files')
        
        # try to rename original folder
        try:
            os.rename(folder_name, new_folder_name)
            # if error, 
        except OSError:
            existing_base_folder = os.getcwd()+"/"+new_folder_name
            justcreated_base_folder = os.getcwd()+"/"+folder_name
                 
            # get a list of all files in the folder
            generated_files = os.listdir(justcreated_base_folder)
            
            # copy each file to the existing folder
            for generated_file in generated_files:
                to_copy = justcreated_base_folder+"/"+generated_file
                shutil.copy(to_copy, existing_base_folder)
  
            # delete the newly created _files folder
            shutil.rmtree(justcreated_base_folder)

# %% [markdown]
# ## Search Through Contents Of All Markdown Files (manually generated and generated by a jupyter notebook) And Fix Links So That They Point To Folders Created Above

# %%
def replaceAll(file,searchExp,replaceExp):
    for line in fileinput.input(file, inplace=1):
        if searchExp in line:
            line = line.replace(searchExp,replaceExp)
        sys.stdout.write(line)

# Find all markdown files in all content folders
all_md_files = [os.path.join(root, name)
               for root, dirs, files in os.walk(path)
               for name in files
               if name.endswith((".md"))]

for file in all_md_files:
    with open(file,'r') as f:
        filedata = f.read()
        # Find all markdown link syntaxes
        md_links = re.findall('!\\[[^\\]]+\\]\\([^)]+\\)', filedata)

        # For each markdown link
        for link in md_links:
            # Replace the full file path
            md_image_path = re.search(r'\((.*?)\)', link).group(1)
            md_image_filename = os.path.basename(md_image_path)
            md_image_title = re.search(r'\[(.*?)\]', link).group(1)

            new_link = "!["+md_image_title+"]("+md_image_filename+")"

            replaceAll(file, link, new_link)
            print("Replaced", link, "with", new_link)
# Out:
# Replaced ![png](demonstrate_the_central_limit_theorem_files/demonstrate_the_central_limit_theorem_5_1.png) with ![png](demonstrate_the_central_limit_theorem_5_1.png)
# Replaced ![png](demonstrate_the_central_limit_theorem_files/demonstrate_the_central_limit_theorem_11_1.png) with ![png](demonstrate_the_central_limit_theorem_11_1.png)
# Replaced ![png](probability_mass_functions_files/probability_mass_functions_10_0.png) with ![png](probability_mass_functions_10_0.png)
# Replaced ![png](launch_instance.png) with ![png](launch_instance.png)
# Replaced ![Select Ubuntu](select_ubuntu.png) with ![Select Ubuntu](select_ubuntu.png)
# Replaced ![Select Micro T2](select_micro_t2.png) with ![Select Micro T2](select_micro_t2.png)
# Replaced ![png](comes_with_8gig.png) with ![png](comes_with_8gig.png)
# Replaced ![png](security_group.png) with ![png](security_group.png)
# Replaced ![png](key_pair.png) with ![png](key_pair.png)
# Replaced ![connect_1](connect_1.png) with ![connect_1](connect_1.png)
# Replaced ![connect_2](connect_2.png) with ![connect_2](connect_2.png)
# Replaced ![terminal](terminal.png) with ![terminal](terminal.png)
# Replaced ![ssh](ssh.png) with ![ssh](ssh.png)
# Replaced ![success!](command.png) with ![success!](command.png)
# Replaced ![Anaconda!](anaconda.png) with ![Anaconda!](anaconda.png)
# Replaced ![Anaconda!](anaconda_download.png) with ![Anaconda!](anaconda_download.png)
# Replaced ![Anaconda!](anaconda_install.png) with ![Anaconda!](anaconda_install.png)
# Replaced ![Vim](vi.png) with ![Vim](vi.png)
# Replaced ![Vim](vi_2.png) with ![Vim](vi_2.png)
# Replaced ![jupyter](load_jupyter.png) with ![jupyter](load_jupyter.png)
# Replaced ![chrome](chrome1.png) with ![chrome](chrome1.png)
# Replaced ![chrome](chrome2.png) with ![chrome](chrome2.png)
# Replaced ![chrome](chrome3.png) with ![chrome](chrome3.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_6_0.png) with ![png](set_the_color_of_a_matplotlib_6_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_7_0.png) with ![png](set_the_color_of_a_matplotlib_7_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_8_0.png) with ![png](set_the_color_of_a_matplotlib_8_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_9_0.png) with ![png](set_the_color_of_a_matplotlib_9_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_10_0.png) with ![png](set_the_color_of_a_matplotlib_10_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_11_0.png) with ![png](set_the_color_of_a_matplotlib_11_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_12_0.png) with ![png](set_the_color_of_a_matplotlib_12_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_13_0.png) with ![png](set_the_color_of_a_matplotlib_13_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_14_0.png) with ![png](set_the_color_of_a_matplotlib_14_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_15_0.png) with ![png](set_the_color_of_a_matplotlib_15_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_16_0.png) with ![png](set_the_color_of_a_matplotlib_16_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_17_0.png) with ![png](set_the_color_of_a_matplotlib_17_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_18_0.png) with ![png](set_the_color_of_a_matplotlib_18_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_19_0.png) with ![png](set_the_color_of_a_matplotlib_19_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_20_0.png) with ![png](set_the_color_of_a_matplotlib_20_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_21_0.png) with ![png](set_the_color_of_a_matplotlib_21_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_22_0.png) with ![png](set_the_color_of_a_matplotlib_22_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_23_0.png) with ![png](set_the_color_of_a_matplotlib_23_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_24_0.png) with ![png](set_the_color_of_a_matplotlib_24_0.png)
# Replaced ![png](set_the_color_of_a_matplotlib_files/set_the_color_of_a_matplotlib_25_0.png) with ![png](set_the_color_of_a_matplotlib_25_0.png)
# Replaced ![png](pandas_with_seaborn_files/pandas_with_seaborn_6_1.png) with ![png](pandas_with_seaborn_6_1.png)
# Replaced ![png](pandas_with_seaborn_files/pandas_with_seaborn_8_1.png) with ![png](pandas_with_seaborn_8_1.png)
# Replaced ![png](pandas_with_seaborn_files/pandas_with_seaborn_9_1.png) with ![png](pandas_with_seaborn_9_1.png)
# Replaced ![png](pandas_with_seaborn_files/pandas_with_seaborn_10_1.png) with ![png](pandas_with_seaborn_10_1.png)
# Replaced ![png](pandas_with_seaborn_files/pandas_with_seaborn_12_0.png) with ![png](pandas_with_seaborn_12_0.png)
# Replaced ![png](pandas_with_seaborn_files/pandas_with_seaborn_14_1.png) with ![png](pandas_with_seaborn_14_1.png)
# Replaced ![png](pandas_with_seaborn_files/pandas_with_seaborn_16_1.png) with ![png](pandas_with_seaborn_16_1.png)
# Replaced ![png](pandas_with_seaborn_files/pandas_with_seaborn_18_1.png) with ![png](pandas_with_seaborn_18_1.png)
# Replaced ![png](pandas_with_seaborn_files/pandas_with_seaborn_20_1.png) with ![png](pandas_with_seaborn_20_1.png)
# Replaced ![png](pandas_normalize_column_files/pandas_normalize_column_5_1.png) with ![png](pandas_normalize_column_5_1.png)
# Replaced ![png](pandas_normalize_column_files/pandas_normalize_column_9_1.png) with ![png](pandas_normalize_column_9_1.png)
# Replaced ![png](pandas_time_series_basics_files/pandas_time_series_basics_29_1.png) with ![png](pandas_time_series_basics_29_1.png)
# Replaced ![png](scipy_simple_clustering_files/scipy_simple_clustering_26_1.png) with ![png](scipy_simple_clustering_26_1.png)
# Replaced ![png](aisle_seat_probabilities_files/aisle_seat_probabilities_20_1.png) with ![png](aisle_seat_probabilities_20_1.png)
# Replaced ![png](matplotlib_simple_scatterplot_files/matplotlib_simple_scatterplot_6_0.png) with ![png](matplotlib_simple_scatterplot_6_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_5_0.png) with ![png](seaborn_color_palettes_5_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_6_0.png) with ![png](seaborn_color_palettes_6_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_7_0.png) with ![png](seaborn_color_palettes_7_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_8_0.png) with ![png](seaborn_color_palettes_8_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_9_0.png) with ![png](seaborn_color_palettes_9_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_10_0.png) with ![png](seaborn_color_palettes_10_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_11_0.png) with ![png](seaborn_color_palettes_11_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_12_0.png) with ![png](seaborn_color_palettes_12_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_13_0.png) with ![png](seaborn_color_palettes_13_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_14_0.png) with ![png](seaborn_color_palettes_14_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_15_0.png) with ![png](seaborn_color_palettes_15_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_16_0.png) with ![png](seaborn_color_palettes_16_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_17_0.png) with ![png](seaborn_color_palettes_17_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_18_0.png) with ![png](seaborn_color_palettes_18_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_19_0.png) with ![png](seaborn_color_palettes_19_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_20_0.png) with ![png](seaborn_color_palettes_20_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_21_0.png) with ![png](seaborn_color_palettes_21_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_22_0.png) with ![png](seaborn_color_palettes_22_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_23_0.png) with ![png](seaborn_color_palettes_23_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_24_0.png) with ![png](seaborn_color_palettes_24_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_25_0.png) with ![png](seaborn_color_palettes_25_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_26_0.png) with ![png](seaborn_color_palettes_26_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_27_0.png) with ![png](seaborn_color_palettes_27_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_29_0.png) with ![png](seaborn_color_palettes_29_0.png)
# Replaced ![png](seaborn_color_palettes_files/seaborn_color_palettes_31_1.png) with ![png](seaborn_color_palettes_31_1.png)
# Replaced ![png](seaborn_scatterplot_files/seaborn_scatterplot_7_1.png) with ![png](seaborn_scatterplot_7_1.png)
# Replaced ![png](seaborn_pandas_timeseries_plot_files/seaborn_pandas_timeseries_plot_5_1.png) with ![png](seaborn_pandas_timeseries_plot_5_1.png)
# Replaced ![png](seaborn_pandas_timeseries_plot_files/seaborn_pandas_timeseries_plot_7_1.png) with ![png](seaborn_pandas_timeseries_plot_7_1.png)
# Replaced ![png](matplotlib_grouped_bar_plot_files/matplotlib_grouped_bar_plot_6_0.png) with ![png](matplotlib_grouped_bar_plot_6_0.png)
# Replaced ![png](matplotlib_simple_example_files/matplotlib_simple_example_6_1.png) with ![png](matplotlib_simple_example_6_1.png)
# Replaced ![png](matplotlib_percentage_stacked_bar_plot_files/matplotlib_percentage_stacked_bar_plot_6_0.png) with ![png](matplotlib_percentage_stacked_bar_plot_6_0.png)
# Replaced ![png](matplotlib_histogram_files/matplotlib_histogram_6_0.png) with ![png](matplotlib_histogram_6_0.png)
# Replaced ![png](matplotlib_histogram_files/matplotlib_histogram_8_0.png) with ![png](matplotlib_histogram_8_0.png)
# Replaced ![png](matplotlib_scatterplot_from_pandas_files/matplotlib_scatterplot_from_pandas_6_1.png) with ![png](matplotlib_scatterplot_from_pandas_6_1.png)
# Replaced ![png](matplotlib_scatterplot_from_pandas_files/matplotlib_scatterplot_from_pandas_8_1.png) with ![png](matplotlib_scatterplot_from_pandas_8_1.png)
# Replaced ![png](matplotlib_bar_plot_files/matplotlib_bar_plot_6_0.png) with ![png](matplotlib_bar_plot_6_0.png)
# Replaced ![png](matplotlib_back_to_back_bar_plot_files/matplotlib_back_to_back_bar_plot_6_0.png) with ![png](matplotlib_back_to_back_bar_plot_6_0.png)
# Replaced ![png](matplotlib_pie_chart_files/matplotlib_pie_chart_7_0.png) with ![png](matplotlib_pie_chart_7_0.png)
# Replaced ![png](loading_scikit-learns_digits-dataset_files/loading_scikit-learns_digits-dataset_7_1.png) with ![png](loading_scikit-learns_digits-dataset_7_1.png)
# Replaced ![png](make_simulated_data_for_clustering_files/make_simulated_data_for_clustering_6_0.png) with ![png](make_simulated_data_for_clustering_6_0.png)
# Replaced ![png](k-nearest_neighbors_classifer_files/k-nearest_neighbors_classifer_9_1.png) with ![png](k-nearest_neighbors_classifer_9_1.png)
# Replaced ![png](plot_the_validation_curve_files/plot_the_validation_curve_7_0.png) with ![png](plot_the_validation_curve_7_0.png)
# Replaced ![png](plot_the_receiving_operating_characteristic_curve_files/plot_the_receiving_operating_characteristic_curve_13_0.png) with ![png](plot_the_receiving_operating_characteristic_curve_13_0.png)
# Replaced ![png](plot_the_learning_curve_files/plot_the_learning_curve_7_0.png) with ![png](plot_the_learning_curve_7_0.png)
# Replaced ![png](detect_edges_files/detect_edges_8_0.png) with ![png](detect_edges_8_0.png)
# Replaced ![png](isolate_colors_files/isolate_colors_14_0.png) with ![png](isolate_colors_14_0.png)
# Replaced ![png](harris_corner_detector_files/harris_corner_detector_13_0.png) with ![png](harris_corner_detector_13_0.png)
# Replaced ![png](sharpen_images_files/sharpen_images_8_0.png) with ![png](sharpen_images_8_0.png)
# Replaced ![png](remove_backgrounds_files/remove_backgrounds_13_0.png) with ![png](remove_backgrounds_13_0.png)
# Replaced ![png](save_images_files/save_images_4_0.png) with ![png](save_images_4_0.png)
# Replaced ![png](enhance_contrast_of_greyscale_image_files/enhance_contrast_of_greyscale_image_8_0.png) with ![png](enhance_contrast_of_greyscale_image_8_0.png)
# Replaced ![png](enhance_contrast_of_color_image_files/enhance_contrast_of_color_image_12_0.png) with ![png](enhance_contrast_of_color_image_12_0.png)
# Replaced ![png](load_images_files/load_images_4_0.png) with ![png](load_images_4_0.png)
# Replaced ![png](load_images_files/load_images_6_0.png) with ![png](load_images_6_0.png)
# Replaced ![png](ski-tomasi_corner_detector_files/ski-tomasi_corner_detector_12_0.png) with ![png](ski-tomasi_corner_detector_12_0.png)
# Replaced ![png](binarize_image_files/binarize_image_8_0.png) with ![png](binarize_image_8_0.png)
# Replaced ![png](blurring_images_files/blurring_images_8_0.png) with ![png](blurring_images_8_0.png)
# Replaced ![png](using_mean_color_as_a_feature_files/using_mean_color_as_a_feature_10_0.png) with ![png](using_mean_color_as_a_feature_10_0.png)
# Replaced ![png](cropping_images_files/cropping_images_8_0.png) with ![png](cropping_images_8_0.png)
# Replaced ![png](linear_regression_scikitlearn_files/linear_regression_scikitlearn_12_1.png) with ![png](linear_regression_scikitlearn_12_1.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_9_0.png) with ![png](svc_parameters_using_rbf_kernel_9_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_11_0.png) with ![png](svc_parameters_using_rbf_kernel_11_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_15_0.png) with ![png](svc_parameters_using_rbf_kernel_15_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_17_0.png) with ![png](svc_parameters_using_rbf_kernel_17_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_19_0.png) with ![png](svc_parameters_using_rbf_kernel_19_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_21_0.png) with ![png](svc_parameters_using_rbf_kernel_21_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_24_0.png) with ![png](svc_parameters_using_rbf_kernel_24_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_26_0.png) with ![png](svc_parameters_using_rbf_kernel_26_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_28_0.png) with ![png](svc_parameters_using_rbf_kernel_28_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_30_0.png) with ![png](svc_parameters_using_rbf_kernel_30_0.png)
# Replaced ![png](svc_parameters_using_rbf_kernel_files/svc_parameters_using_rbf_kernel_32_0.png) with ![png](svc_parameters_using_rbf_kernel_32_0.png)
# Replaced ![png](plot_support_vector_classifier_hyperplane_files/plot_support_vector_classifier_hyperplane_11_0.png) with ![png](plot_support_vector_classifier_hyperplane_11_0.png)
# Replaced ![png](feature_importance_files/feature_importance_11_0.png) with ![png](feature_importance_11_0.png)
# Replaced ![png](visualize_a_decision_tree_files/visualize_a_decision_tree_8_0.png) with ![png](visualize_a_decision_tree_8_0.png)
# Replaced ![Solution of rebel mobilization](rebel_mobilization.png) with ![Solution of rebel mobilization](rebel_mobilization.png)
# Replaced ![Every Day At Techstars Cloud](Popily-25.jpg) with ![Every Day At Techstars Cloud](Popily-25.jpg)
# Replaced ![Every Day At Techstars Cloud](1.png) with ![Every Day At Techstars Cloud](1.png)
# Replaced ![Hours Of Sleep During Techstars](6.png) with ![Hours Of Sleep During Techstars](6.png)
# Replaced ![png](visualize_performance_history_files/visualize_performance_history_12_0.png) with ![png](visualize_performance_history_12_0.png)
# Replaced ![png](visualize_loss_history_files/visualize_loss_history_12_0.png) with ![png](visualize_loss_history_12_0.png)
# Replaced ![svg](visualize_neural_network_architecture_files/visualize_neural_network_architecture_6_0.svg) with ![svg](visualize_neural_network_architecture_6_0.svg)
